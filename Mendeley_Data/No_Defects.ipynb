# %% [markdown]
# 目标：请帮我在当前的jupyter文件中编写一段python代码，把这个.xlsx文件转化成json文件，我只需要每个工作簿中的前三列数据。
#
# 要求：
# 1. 只使用pandas包，和numpy包（如果必要的话），不要使用其它python包。
#
# 2. 把第二行的单位合并到第一行的标签，比如： "Time_sec", "Extension_mm", "Load_N".
#
# 3. 输出的Json格式要求：最外层的键使用工作簿名称，比如： {"0_1": [{"Time (sec)": 20.3, ...}, ...], "0_2": [...]}.
#
# 4. 将数值从字符串格式转化成浮点数格式。
#
# 流程：执行任务前先阅读这个.xlsx文件的内容，然后与我讨论python代码的方案。在我选择好方案后，再执行生成python代码的任务。
